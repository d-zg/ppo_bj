# %%
# for evaluating a trained model
from sb3_utils import load_model, test_policy_table, plot_policy_and_split_tables, create_env, evaluate_reward

# %%
model = load_model("/Users/andrewzhang/Projects/blackjackproj/another_two.zip")
# Out:
# Model loaded successfully from /Users/andrewzhang/Projects/blackjackproj/another_two.zip

# %%
policy_tables, split_tables = test_policy_table(model)

# %%
for i in range(11):
    plot_policy_and_split_tables(policy_tables, split_tables, i)

# %%
eval_env = create_env("human")

# %%
evaluate_reward(model, eval_env, 50000)
# Out:
# Initial evaluation: Mean Reward = 0.01 +/- 1.15
# (0.00621, 1.146990163820074)
